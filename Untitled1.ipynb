# %%
# Paso 1: importar librerías
import pandas as pd
import matplotlib.pyplot as plt

# Paso 2: cargar el archivo
df = pd.read_csv('tendencias_moda_sostenible.csv')

# Paso 3: visualizar las primeras filas (opcional)
df.head()

# Paso 4: graficar las tendencias
df.set_index('Fecha', inplace=True)
df.plot(figsize=(12, 6), title='📈 Tendencias de Moda Sostenible en Colombia (simulado)')
plt.ylabel("Índice de Búsqueda (0 a 100)")
plt.xlabel("Fecha")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-2-502fde595778>:17: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
